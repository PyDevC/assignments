# %%
# import libraries of data analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading dataset
# dataset from https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data

# %%
# path to the dataset
path = '../data/house-prices-advanced-regression-techniques/train.csv'
df = pd.read_csv(path)

# view first 10 rows of the dataset
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# ## Target variable
# The last column 'SalePrice' is the target variable
# Rest of the columns are either features or bloated data.
# target variable wil be seperated after cleaning of data.

# %% [markdown]
# ## Checking missing values
# ## Only Columns with missing will be displayed
# **drop** columns which have more than 200 null values

# %%
# Total nan values
print("Total number of null values")
print(df.isnull().sum().sum())
# get all the columns with nan values
nan_cols = [i for i in df.columns if df[i].isnull().any()]

drop_list = [] # this contains all the columns to be droped later

for i in nan_cols:
    print(i, df[i].isnull().sum())
    if df[i].isnull().sum() > 200:
        drop_list.append(i)

df.drop(columns=drop_list, inplace=True)
# Out:
# Total number of null values
# 7829
# LotFrontage 259
# MasVnrArea 8
# GarageYrBlt 81
# Alley 1369
# MasVnrType 872
# BsmtQual 37
# BsmtCond 37
# BsmtExposure 38
# BsmtFinType1 37
# BsmtFinType2 38
# Electrical 1
# FireplaceQu 690
# GarageType 81
# GarageFinish 81
# GarageQual 81
# GarageCond 81
# PoolQC 1453
# Fence 1179
# MiscFeature 1406

# %% [markdown]
# # Numerical and categroical analysis

# %%
# Sperate dataset into numerical and categorical dataset.
num_df = df.select_dtypes(include=[np.number])
cat_df = df.select_dtypes(exclude=[np.number])

# basic statistics of numerical data
num_df.describe()
# Out:
#                 Id   MSSubClass        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean    730.500000    56.897260   10516.828082     6.099315     5.575342
# std     421.610009    42.300571    9981.264932     1.382997     1.112799
# min       1.000000    20.000000    1300.000000     1.000000     1.000000
# 25%     365.750000    20.000000    7553.500000     5.000000     5.000000
# 50%     730.500000    50.000000    9478.500000     6.000000     5.000000
# 75%    1095.250000    70.000000   11601.500000     7.000000     6.000000
# max    1460.000000   190.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# min    1872.000000   1950.000000     0.000000     0.000000     0.000000  ...
# 25%    1954.000000   1967.000000     0.000000     0.000000     0.000000  ...
# 50%    1973.000000   1994.000000     0.000000   383.500000     0.000000  ...
# 75%    2000.000000   2004.000000   166.000000   712.250000     0.000000  ...
# max    2010.000000   2010.000000  1600.000000  5644.000000  1474.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 37 columns]

# %%
frequency = {}

for i in cat_df.columns:
    for j in list([cat_df[i].unique(), cat_df[i].value_counts()]):
        print(f"*****************{i}*****************")
        print(j[:5], end="\n\n\n")
# Out:
# *****************MSZoning*****************
# ['RL' 'RM' 'C (all)' 'FV' 'RH']
#
#
# *****************MSZoning*****************
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: count, dtype: int64
#
#
# *****************Street*****************
# ['Pave' 'Grvl']
#
#
# *****************Street*****************
# Street
# Pave    1454
# Grvl       6
# Name: count, dtype: int64
#
#
# *****************LotShape*****************
# ['Reg' 'IR1' 'IR2' 'IR3']
#
#
# *****************LotShape*****************
# LotShape
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: count, dtype: int64
#
#
# *****************LandContour*****************
# ['Lvl' 'Bnk' 'Low' 'HLS']
#
#
# *****************LandContour*****************
# LandContour
# Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# Name: count, dtype: int64
#
#
# *****************Utilities*****************
# ['AllPub' 'NoSeWa']
#
#
# *****************Utilities*****************
# Utilities
# AllPub    1459
# NoSeWa       1
# Name: count, dtype: int64
#
#
# *****************LotConfig*****************
# ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
#
#
# *****************LotConfig*****************
# LotConfig
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: count, dtype: int64
#
#
# *****************LandSlope*****************
# ['Gtl' 'Mod' 'Sev']
#
#
# *****************LandSlope*****************
# LandSlope
# Gtl    1382
# Mod      65
# Sev      13
# Name: count, dtype: int64
#
#
# *****************Neighborhood*****************
# ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel']
#
#
# *****************Neighborhood*****************
# Neighborhood
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Name: count, dtype: int64
#
#
# *****************Condition1*****************
# ['Norm' 'Feedr' 'PosN' 'Artery' 'RRAe']
#
#
# *****************Condition1*****************
# Condition1
# Norm      1260
# Feedr       81
# Artery      48
# RRAn        26
# PosN        19
# Name: count, dtype: int64
#
#
# *****************Condition2*****************
# ['Norm' 'Artery' 'RRNn' 'Feedr' 'PosN']
#
#
# *****************Condition2*****************
# Condition2
# Norm      1445
# Feedr        6
# Artery       2
# RRNn         2
# PosN         2
# Name: count, dtype: int64
#
#
# *****************BldgType*****************
# ['1Fam' '2fmCon' 'Duplex' 'TwnhsE' 'Twnhs']
#
#
# *****************BldgType*****************
# BldgType
# 1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: count, dtype: int64
#
#
# *****************HouseStyle*****************
# ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer']
#
#
# *****************HouseStyle*****************
# HouseStyle
# 1Story    726
# 2Story    445
# 1.5Fin    154
# SLvl       65
# SFoyer     37
# Name: count, dtype: int64
#
#
# *****************RoofStyle*****************
# ['Gable' 'Hip' 'Gambrel' 'Mansard' 'Flat']
#
#
# *****************RoofStyle*****************
# RoofStyle
# Gable      1141
# Hip         286
# Flat         13
# Gambrel      11
# Mansard       7
# Name: count, dtype: int64
#
#
# *****************RoofMatl*****************
# ['CompShg' 'WdShngl' 'Metal' 'WdShake' 'Membran']
#
#
# *****************RoofMatl*****************
# RoofMatl
# CompShg    1434
# Tar&Grv      11
# WdShngl       6
# WdShake       5
# Metal         1
# Name: count, dtype: int64
#
#
# *****************Exterior1st*****************
# ['VinylSd' 'MetalSd' 'Wd Sdng' 'HdBoard' 'BrkFace']
#
#
# *****************Exterior1st*****************
# Exterior1st
# VinylSd    515
# HdBoard    222
# MetalSd    220
# Wd Sdng    206
# Plywood    108
# Name: count, dtype: int64
#
#
# *****************Exterior2nd*****************
# ['VinylSd' 'MetalSd' 'Wd Shng' 'HdBoard' 'Plywood']
#
#
# *****************Exterior2nd*****************
# Exterior2nd
# VinylSd    504
# MetalSd    214
# HdBoard    207
# Wd Sdng    197
# Plywood    142
# Name: count, dtype: int64
#
#
# *****************ExterQual*****************
# ['Gd' 'TA' 'Ex' 'Fa']
#
#
# *****************ExterQual*****************
# ExterQual
# TA    906
# Gd    488
# Ex     52
# Fa     14
# Name: count, dtype: int64
#
#
# *****************ExterCond*****************
# ['TA' 'Gd' 'Fa' 'Po' 'Ex']
#
#
# *****************ExterCond*****************
# ExterCond
# TA    1282
# Gd     146
# Fa      28
# Ex       3
# Po       1
# Name: count, dtype: int64
#
#
# *****************Foundation*****************
# ['PConc' 'CBlock' 'BrkTil' 'Wood' 'Slab']
#
#
# *****************Foundation*****************
# Foundation
# PConc     647
# CBlock    634
# BrkTil    146
# Slab       24
# Stone       6
# Name: count, dtype: int64
#
#
# *****************BsmtQual*****************
# ['Gd' 'TA' 'Ex' nan 'Fa']
#
#
# *****************BsmtQual*****************
# BsmtQual
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: count, dtype: int64
#
#
# *****************BsmtCond*****************
# ['TA' 'Gd' nan 'Fa' 'Po']
#
#
# *****************BsmtCond*****************
# BsmtCond
# TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: count, dtype: int64
#
#
# *****************BsmtExposure*****************
# ['No' 'Gd' 'Mn' 'Av' nan]
#
#
# *****************BsmtExposure*****************
# BsmtExposure
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: count, dtype: int64
#
#
# *****************BsmtFinType1*****************
# ['GLQ' 'ALQ' 'Unf' 'Rec' 'BLQ']
#
#
# *****************BsmtFinType1*****************
# BsmtFinType1
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# Name: count, dtype: int64
#
#
# *****************BsmtFinType2*****************
# ['Unf' 'BLQ' nan 'ALQ' 'Rec']
#
#
# *****************BsmtFinType2*****************
# BsmtFinType2
# Unf    1256
# Rec      54
# LwQ      46
# BLQ      33
# ALQ      19
# Name: count, dtype: int64
#
#
# *****************Heating*****************
# ['GasA' 'GasW' 'Grav' 'Wall' 'OthW']
#
#
# *****************Heating*****************
# Heating
# GasA    1428
# GasW      18
# Grav       7
# Wall       4
# OthW       2
# Name: count, dtype: int64
#
#
# *****************HeatingQC*****************
# ['Ex' 'Gd' 'TA' 'Fa' 'Po']
#
#
# *****************HeatingQC*****************
# HeatingQC
# Ex    741
# TA    428
# Gd    241
# Fa     49
# Po      1
# Name: count, dtype: int64
#
#
# *****************CentralAir*****************
# ['Y' 'N']
#
#
# *****************CentralAir*****************
# CentralAir
# Y    1365
# N      95
# Name: count, dtype: int64
#
#
# *****************Electrical*****************
# ['SBrkr' 'FuseF' 'FuseA' 'FuseP' 'Mix']
#
#
# *****************Electrical*****************
# Electrical
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: count, dtype: int64
#
#
# *****************KitchenQual*****************
# ['Gd' 'TA' 'Ex' 'Fa']
#
#
# *****************KitchenQual*****************
# KitchenQual
# TA    735
# Gd    586
# Ex    100
# Fa     39
# Name: count, dtype: int64
#
#
# *****************Functional*****************
# ['Typ' 'Min1' 'Maj1' 'Min2' 'Mod']
#
#
# *****************Functional*****************
# Functional
# Typ     1360
# Min2      34
# Min1      31
# Mod       15
# Maj1      14
# Name: count, dtype: int64
#
#
# *****************GarageType*****************
# ['Attchd' 'Detchd' 'BuiltIn' 'CarPort' nan]
#
#
# *****************GarageType*****************
# GarageType
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# Name: count, dtype: int64
#
#
# *****************GarageFinish*****************
# ['RFn' 'Unf' 'Fin' nan]
#
#
# *****************GarageFinish*****************
# GarageFinish
# Unf    605
# RFn    422
# Fin    352
# Name: count, dtype: int64
#
#
# *****************GarageQual*****************
# ['TA' 'Fa' 'Gd' nan 'Ex']
#
#
# *****************GarageQual*****************
# GarageQual
# TA    1311
# Fa      48
# Gd      14
# Ex       3
# Po       3
# Name: count, dtype: int64
#
#
# *****************GarageCond*****************
# ['TA' 'Fa' nan 'Gd' 'Po']
#
#
# *****************GarageCond*****************
# GarageCond
# TA    1326
# Fa      35
# Gd       9
# Po       7
# Ex       2
# Name: count, dtype: int64
#
#
# *****************PavedDrive*****************
# ['Y' 'N' 'P']
#
#
# *****************PavedDrive*****************
# PavedDrive
# Y    1340
# N      90
# P      30
# Name: count, dtype: int64
#
#
# *****************SaleType*****************
# ['WD' 'New' 'COD' 'ConLD' 'ConLI']
#
#
# *****************SaleType*****************
# SaleType
# WD       1267
# New       122
# COD        43
# ConLD       9
# ConLI       5
# Name: count, dtype: int64
#
#
# *****************SaleCondition*****************
# ['Normal' 'Abnorml' 'Partial' 'AdjLand' 'Alloca']
#
#
# *****************SaleCondition*****************
# SaleCondition
# Normal     1198
# Partial     125
# Abnorml     101
# Family       20
# Alloca       12
# Name: count, dtype: int64

# %% [markdown]
# # removing duplicates
# No duplicates can be removed as duplicate rows are not identifiers but categories.

# %% [markdown]
# # Split dataset
#
# - Combine numerical and categorical dataset
# - Drop all null values
# - Identify the target variable
# - Split the train and test data

# %%
# check if both numerical and categorical dataframes are of same dimensions
print(num_df.shape)
print(cat_df.shape)

df = pd.concat([num_df, cat_df], axis=1)
# Out:
# (1460, 37)
# (1460, 37)

# %%
df.head()
# Out:
#    Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0   1          60     8450            7            5       2003          2003
# 1   2          20     9600            6            8       1976          1976
# 2   3          60    11250            7            5       2001          2002
# 3   4          70     9550            7            5       1915          1970
# 4   5          60    14260            8            5       2000          2000
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  Electrical  KitchenQual  \
# 0       196.0         706           0  ...       SBrkr           Gd
# 1         0.0         978           0  ...       SBrkr           TA
# 2       162.0         486           0  ...       SBrkr           Gd
# 3         0.0         216           0  ...       SBrkr           Gd
# 4       350.0         655           0  ...       SBrkr           Gd
#
#    Functional  GarageType  GarageFinish  GarageQual  GarageCond  PavedDrive  \
# 0         Typ      Attchd           RFn          TA          TA           Y
# 1         Typ      Attchd           RFn          TA          TA           Y
# 2         Typ      Attchd           RFn          TA          TA           Y
# 3         Typ      Detchd           Unf          TA          TA           Y
# 4         Typ      Attchd           RFn          TA          TA           Y
#
#    SaleType  SaleCondition
# 0        WD         Normal
# 1        WD         Normal
# 2        WD         Normal
# 3        WD        Abnorml
# 4        WD         Normal
#
# [5 rows x 74 columns]

# %%
df.dropna()
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        1          60     8450            7            5       2003
# 1        2          20     9600            6            8       1976
# 2        3          60    11250            7            5       2001
# 3        4          70     9550            7            5       1915
# 4        5          60    14260            8            5       2000
# ...    ...         ...      ...          ...          ...        ...
# 1455  1456          60     7917            6            5       1999
# 1456  1457          20    13175            6            6       1978
# 1457  1458          70     9042            7            9       1941
# 1458  1459          20     9717            5            6       1950
# 1459  1460          20     9937            5            6       1965
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  Electrical  \
# 0             2003       196.0         706           0  ...       SBrkr
# 1             1976         0.0         978           0  ...       SBrkr
# 2             2002       162.0         486           0  ...       SBrkr
# 3             1970         0.0         216           0  ...       SBrkr
# 4             2000       350.0         655           0  ...       SBrkr
# ...            ...         ...         ...         ...  ...         ...
# 1455          2000         0.0           0           0  ...       SBrkr
# 1456          1988       119.0         790         163  ...       SBrkr
# 1457          2006         0.0         275           0  ...       SBrkr
# 1458          1996         0.0          49        1029  ...       FuseA
# 1459          1965         0.0         830         290  ...       SBrkr
#
#       KitchenQual  Functional  GarageType  GarageFinish  GarageQual  \
# 0              Gd         Typ      Attchd           RFn          TA
# 1              TA         Typ      Attchd           RFn          TA
# 2              Gd         Typ      Attchd           RFn          TA
# 3              Gd         Typ      Detchd           Unf          TA
# 4              Gd         Typ      Attchd           RFn          TA
# ...           ...         ...         ...           ...         ...
# 1455           TA         Typ      Attchd           RFn          TA
# 1456           TA        Min1      Attchd           Unf          TA
# 1457           Gd         Typ      Attchd           RFn          TA
# 1458           Gd         Typ      Attchd           Unf          TA
# 1459           TA         Typ      Attchd           Fin          TA
#
#       GarageCond  PavedDrive  SaleType  SaleCondition
# 0             TA           Y        WD         Normal
# 1             TA           Y        WD         Normal
# 2             TA           Y        WD         Normal
# 3             TA           Y        WD        Abnorml
# 4             TA           Y        WD         Normal
# ...          ...         ...       ...            ...
# 1455          TA           Y        WD         Normal
# 1456          TA           Y        WD         Normal
# 1457          TA           Y        WD         Normal
# 1458          TA           Y        WD         Normal
# 1459          TA           Y        WD         Normal
#
# [1338 rows x 74 columns]

# %%
target = df['SalePrice']
df.drop(columns=['SalePrice'], inplace=True)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df, target, test_size=0.2, random_state=2)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1168, 73)
# (292, 73)
# (1168,)
# (292,)

# %% [markdown]
# # plotting
# Study data visually
#
# TODO:
# - subplot for getting sales price in each category
# - subplot for line for numerical data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def histogram(data, name):
    plt.hist(data, bins=30, color='', )
    plt.xlabel(name)
    plt.ylabel('Sale Price')
    plt.title(f'{name} Vs Sale Price')
    plt.show()

# %%
num_df = df.select_dtypes(include=np.number)
cat_df = df.select_dtypes(exclude=np.number)

for column in cat_df.columns:
    histogram(df[column], column)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 5
#       2 cat_df = df.select_dtypes(exclude=np.number)
#       4 for column in cat_df.columns:
# ----> 5     histogram(df[column], column)
#
# Cell In[100], line 2, in histogram(data, name)
#       1 def histogram(data, name):
# ----> 2     plt.hist(data, bins=30)
#       3     plt.xlabel(name)
#       4     plt.ylabel('Sale Price')
#
# File ~/personal/env/python/ml/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/personal/env/python/ml/lib/python3.10/site-packages/matplotlib/pyplot.py:3469, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3444 @_copy_docstring_and_deprecators(Axes.hist)
#    3445 def hist(
#    3446     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3467     BarContainer | Polygon | list[BarContainer | Polygon],
#    3468 ]:
# -> 3469     return gca().hist(
#    3470         x,
#    3471         bins=bins,
#    3472         range=range,
#    3473         density=density,
#    3474         weights=weights,
#    3475         cumulative=cumulative,
#    3476         bottom=bottom,
#    3477         histtype=histtype,
#    3478         align=align,
#    3479         orientation=orientation,
#    3480         rwidth=rwidth,
#    3481         log=log,
#    3482         color=color,
#    3483         label=label,
#    3484         stacked=stacked,
#    3485         **({"data": data} if data is not None else {}),
#    3486         **kwargs,
#    3487     )
#
# File ~/personal/env/python/ml/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/personal/env/python/ml/lib/python3.10/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File ~/personal/env/python/ml/lib/python3.10/site-packages/matplotlib/axes/_axes.py:7014, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7012 if orientation == "vertical":
#    7013     convert_units = self.convert_xunits
# -> 7014     x = [*self._process_unit_info([("x", x[0])], kwargs),
#    7015          *map(convert_units, x[1:])]
#    7016 else:  # horizontal
#    7017     convert_units = self.convert_yunits
#
# File ~/personal/env/python/ml/lib/python3.10/site-packages/matplotlib/axes/_base.py:2617, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2615     # Update from data if axis is already set but no unit is set yet.
#    2616     if axis is not None and data is not None and not axis.have_units():
# -> 2617         axis.update_units(data)
#    2618 for axis_name, axis in axis_map.items():
#    2619     # Return if no axis is set.
#    2620     if axis is None:
#
# File ~/personal/env/python/ml/lib/python3.10/site-packages/matplotlib/axis.py:1765, in Axis.update_units(self, data)
#    1763 neednew = self._converter != converter
#    1764 self._set_converter(converter)
# -> 1765 default = self._converter.default_units(data, self)
#    1766 if default is not None and self.units is None:
#    1767     self.set_units(default)
#
# File ~/personal/env/python/ml/lib/python3.10/site-packages/matplotlib/category.py:106, in StrCategoryConverter.default_units(data, axis)
#     104 # the conversion call stack is default_units -> axis_info -> convert
#     105 if axis.units is None:
# --> 106     axis.set_units(UnitData(data))
#     107 else:
#     108     axis.units.update(data)
#
# File ~/personal/env/python/ml/lib/python3.10/site-packages/matplotlib/category.py:182, in UnitData.__init__(self, data)
#     180 self._counter = itertools.count()
#     181 if data is not None:
# --> 182     self.update(data)
#
# File ~/personal/env/python/ml/lib/python3.10/site-packages/matplotlib/category.py:217, in UnitData.update(self, data)
#     214 convertible = True
#     215 for val in OrderedDict.fromkeys(data):
#     216     # OrderedDict just iterates over unique values in data.
# --> 217     _api.check_isinstance((str, bytes), value=val)
#     218     if convertible:
#     219         # this will only be called so long as convertible is True.
#     220         convertible = self._str_is_convertible(val)
#
# File ~/personal/env/python/ml/lib/python3.10/site-packages/matplotlib/_api/__init__.py:92, in check_isinstance(types, **kwargs)
#      90     names.remove("None")
#      91     names.append("None")
# ---> 92 raise TypeError(
#      93     "{!r} must be an instance of {}, not a {}".format(
#      94         k,
#      95         ", ".join(names[:-1]) + " or " + names[-1]
#      96         if len(names) > 1 else names[0],
#      97         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a float
